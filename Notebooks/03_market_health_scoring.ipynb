# %%
import pandas as pd
import numpy as np

market_features = pd.read_csv("data/processed/market_features.csv")
market_features.head()
# Out:
#       coingecko_id                     pulled_at_utc  current_price_usd  \
# 0          uniswap  2026-01-19T12:34:30.906620+00:00           4.980000
# 1        chainlink  2026-01-19T12:34:45.019802+00:00          12.750000
# 2             aave  2026-01-19T12:34:47.605564+00:00         163.460000
# 3         lido-dao  2026-01-19T12:35:14.316675+00:00           0.546995
# 4  curve-dao-token  2026-01-19T12:35:17.069355+00:00           0.390634
#
#    market_cap_usd  volume_24h_usd  circulating_supply    max_supply  \
# 0    3.160631e+09       382896158        6.346104e+08  1.000000e+09
# 1    9.024027e+09       648920230        7.081000e+08  1.000000e+09
# 2    2.481823e+09       375268933        1.518357e+07  1.600000e+07
# 3    4.629709e+08        56720533        8.465668e+08  1.000000e+09
# 4    5.737410e+08        74930533        1.468781e+09  3.030303e+09
#
#        fdv_usd token_name_x symbol_x  ...                     category  \
# 0   4480843112      Uniswap      UNI  ...                          DEX
# 1  12744001030    Chainlink     LINK  ...  Infrastructure & Middleware
# 2   2615272322         Aave     AAVE  ...          Lending & Borrowing
# 3    546880520     Lido Dao      LDO  ...               Liquid staking
# 4    915416077    Curve DAO      CRV  ...                          DEX
#
#       chain avg_vol_7d avg_vol_30d max_drawdown_365d avg_vol_mcap_ratio  \
# 0  ethereum   0.050157    0.055325         -0.646855           0.086598
# 1  ethereum   0.043385    0.046230         -0.590724           0.065049
# 2  ethereum   0.046889    0.049209         -0.662779           0.119424
# 3  ethereum   0.054956    0.059079         -0.780226           0.131942
# 4  ethereum   0.053969    0.056678         -0.692343           0.202697
#
#   momentum_7v30 flag_zero_market_cap flag_zero_supply flag_missing_fdv
# 0     -0.018016                False            False            False
# 1     -0.013702                False            False            False
# 2     -0.015125                False            False            False
# 3     -0.033136                False            False            False
# 4     -0.010111                False            False            False
#
# [5 rows x 31 columns]

# %%
market_features["peer_group"] = (
    market_features["tier"].astype(str) + "_" +
    market_features["category"].astype(str)
)

# %%
def percentile_score(series, higher_is_better=True):
    pct = series.rank(pct=True)
    if not higher_is_better:
        pct = 1 - pct
    return (pct * 100).clip(0, 100)

# %%
market_features["vol_score"] = (
    market_features
    .groupby("peer_group")["avg_vol_30d"]
    .transform(lambda x: percentile_score(x, higher_is_better=False))
)

# %%
market_features["drawdown_score"] = (
    market_features
    .groupby("peer_group")["max_drawdown_365d"]
    .transform(lambda x: percentile_score(x, higher_is_better=True))
)

# %%
market_features["liquidity_score"] = (
    market_features
    .groupby("peer_group")["avg_vol_mcap_ratio"]
    .transform(lambda x: percentile_score(x, higher_is_better=True))
)

# absolute liquidity floor
market_features.loc[
    market_features["avg_vol_mcap_ratio"] < 0.002,
    "liquidity_score"
] *= 0.5

# %%
market_features["trend_stability_score"] = (
    100 - (market_features["momentum_7v30"].abs() * 100)
).clip(0, 100)

# %%
market_features["market_health_raw"] = (
    0.30 * market_features["vol_score"] +
    0.30 * market_features["drawdown_score"] +
    0.25 * market_features["liquidity_score"] +
    0.15 * market_features["trend_stability_score"]
)

# %%
market_features["penalty"] = 0

market_features.loc[market_features["flag_zero_market_cap"], "penalty"] -= 30
market_features.loc[market_features["flag_zero_supply"], "penalty"] -= 30
market_features.loc[market_features["flag_missing_fdv"], "penalty"] -= 10

market_features["market_health_score"] = (
    market_features["market_health_raw"] +
    market_features["penalty"]
).clip(0, 100)

# %%
market_features.to_csv(
    "data/processed/market_health_scores.csv",
    index=False
)

market_features[
    ["token_name","tier","category","market_health_score"]
].sort_values("market_health_score", ascending=False)
# Out:
#                token_name tier                     category  \
# 13              Shiba Inu    C                         Meme
# 11  Basic Attention Token    C                 Web3 Utility
# 4               Curve DAO    B                          DEX
# 1               Chainlink    A  Infrastructure & Middleware
# 0                 Uniswap    A                          DEX
# 16                  1inch    B               DEX aggregator
# 10          Yearn Finance    C             Yield Strategies
# 6                Compound    B          Lending & Borrowing
# 5               Synthetix    B                  Derivatives
# 8   Ethereum Name Service    B  Infrastructure & Middleware
# 3                Lido Dao    A               Liquid staking
# 17                  Sushi    C                          DEX
# 9             Rocket Pool    B               Liquid Staking
# 19          Voyager Token    D       CEFi Lending Platforms
# 7                Balancer    B                          DEX
# 14        Celsius Network    D       CEFi Lending Platforms
# 2                    Aave    A          Lending & Borrowing
# 12                   Pepe    C                         Meme
# 15                  Maker    A          Lending & Borrowing
# 18              FTX Token    D                          CEX
#
#     market_health_score
# 13            72.152704
# 11            69.944139
# 4             69.848332
# 1             69.794469
# 0             69.729767
# 16            69.725815
# 10            69.711041
# 6             69.599738
# 5             69.592054
# 8             69.518125
# 3             69.502960
# 17            69.457578
# 9             69.376611
# 19            68.534535
# 7             56.860436
# 14            56.789854
# 2             54.773122
# 12            54.717235
# 15                  NaN
# 18                  NaN
